# %% [markdown]
# # Instruction Milestones:

# %% [markdown]
# This returns a code that almost works, tungod lng sa func2 na while 0 <= dest_index < len(board_state) and board_state[dest_index] is None:
#
# need board_state[dest_index][0] dapat para mu work.

# %%
instruction = f"""I have an initial board state (A 1-dimensional array indicated as a Python list). 
I want you to create a code that takes in a board state as an input with the function name 'func1'.

First, create a Piece class that has the attributes:
1. color: Indicates the piece's color (e.g., "r" for red, "b" for blue).
2. value: The numerical value assigned to that piece.
3. is_dama: A Boolean indicating whether the piece is promoted (dama/king) or not.
4. index: this has a default value of 0. This is the position of a piece on the board_state. This should be assigned during the func1 function call.
5. name: should be a string with the format 'name, value'
A piece’s position is determined by its index (0 to 63) in the board list (excluding unusable squares).

The piece should have these dunder methods:
__repr__: it should look like this Piece('r', 2, is_dama=False)
__eq__: it should return a boolean if another object is+ an instance of the Piece class, and their names should be equal
__hash__: the hash of its name


func1 should follow these logic:

1. The function should iterate on each element of the board state. Enumerate the board state so you can get the index (i) and the element.
2. If the element is a string 'X', do nothing.
3. If the element is a List, check the first element of that list.
4. If the first element is None, do nothing. 
5. Else, if it is an instance of the Piece class, if the piece's color is 'r', AND if the piece is a dama, do these following logic: First, assign the index value to the piece's 'index' attribute. Next, call the func2 function, capture its returned key:value pair. Then, update the valid_moves dictionary with this data.
6. After func2 returns the key:value pair of valid moves, merge this pair into the valid_moves dictionary so that all pieces’ moves are recorded.
7. After the function iterates on all element of the board state, return the dictionary of all valid moves.

Logic for func2:
1. The function also takes in a Piece object.
2. Instantiate a list called damamove with the values [7, 9, -9, -7] and a local empty list called moves.
3. Iterate each element on the damamove list. Call the element 'mv'.
4. For each mv in damamove, set dest_index to the piece’s index and initialize an empty list called holder.
5. Use a while True loop to keep adding the move offset (mv) to dest_index and, if the destination square is within range and empty (i.e. a list whose first element is None), append that destination index to holder. Stop when the square is occupied or out-of-bounds.
6. After the loop, convert holder into a tuple and append this tuple to moves (do not include the piece’s index in the tuple).
7. After processing all move directions, simply return the piece index and the list 'moves'.


Here is the board_state:

{board_state}


Include the board state in your code (Place it after the Piece class is created).
"""


# 3. With each destination index, use it to check on the board state.
# 4. If it is a list, check the first element on the list. If it is an instance of the Piece class, then it is an invalid move.
# 5. If it is not an instance of the Piece class, it IS a valid move.
# 6. Else, if it is a string 'X', it is an invalid move.
# 7. Do not include invalid moves to the valid moves of a Piece.
# 8. Return the piece source index and the valid moves by this tuple format: (source index, [valid moves]).

# %% [markdown]
# This returns a code that handles dama movement. However, wrong ang iluwa sa func2

# %%
instruction = f"""
I have an initial board state (A 1-dimensional array indicated as a Python list). 
I want you to create a code that takes in a board state as an input with the function name 'func1'.

First, create a Piece class that has the attributes:
1. color: Indicates the piece's color (e.g., "r" for red, "b" for blue).
2. value: The numerical value assigned to that piece.
3. is_dama: A Boolean indicating whether the piece is promoted (dama/king) or not.
4. index: this has a default value of 0. This is the position of a piece on the board_state. This should be assigned during the func1 function call.
5. name: should be a string with the format 'name, value'
A piece’s position is determined by its index (0 to 63) in the board list (excluding unusable squares).

The piece should have these dunder methods:
__repr__: it should look like this Piece('r', 2, is_dama=False)
__eq__: it should return a boolean if another object is+ an instance of the Piece class, and their names should be equal
__hash__: the hash of its name


func1 should follow these logic:

1. The function should iterate on each element of the board state. Enumerate the board state so you can get the index (i) and the element.
2. If the element is a string 'X', do nothing.
3. If the element is a List, check the first element of that list.
4. If the first element is None, do nothing. 
5. Else, if it is an instance of the Piece class, if the piece's color is 'r', AND if the piece is a dama, do these following logic: First, assign an attribute 'element.index' to the element its index (i). Next, call the func2 function, capture its returned key:value pair. Then, update the valid_moves dictionary with this data.
6. After func2 returns the key:value pair of valid moves, merge this pair into the valid_moves dictionary so that all pieces’ moves are recorded.
7. Print the dictionary of all valid moves.

Logic for func2:
1. The function also takes in a Piece object.
2. Instantiate a list called damamove with the values [7, 9, -9, -7] and a local empty list called moves.
3. Iterate each element on the damamove list. Call the element 'mv'.
4. For each mv in damamove, set dest_index to the piece’s index and initialize an empty list called holder.
5. Use a while True loop to keep adding the move offset (mv) to dest_index and, if the destination square is within range and empty (i.e. a list whose first element is None), append that destination index to holder. Stop when the square is occupied or out-of-bounds.
6. After the loop, convert holder into a tuple and append this tuple to moves (do not include the piece’s index in the tuple).
7. After processing all move directions, simply return the list moves.


Here is the board_state:

[
    [Piece('r', 2, is_dama=False), '*'], 'X', [Piece('r', -5, is_dama=False), '/'], 'X',
    [Piece('r', 8, is_dama=False), '-'], 'X', [Piece('r', -11, is_dama=False), '+'], 'X',
    'X', [Piece('r', -7, is_dama=False), '/'], 'X', [Piece('r', 10, is_dama=False), '*'], 'X',
    [Piece('r', -3, is_dama=False), '+'], 'X', [Piece('r', 0, is_dama=False), '-'],
    [Piece('r', 4, is_dama=False), '-'], 'X', [Piece('r', -1, is_dama=False), '+'], 'X',
    [Piece('r', 6, is_dama=False), '*'], 'X', [Piece('r', -9, is_dama=False), '/'], 'X',
    'X', [None, '+'], 'X', [None, '-'], 'X', [None, '/'], 'X', [None, '*'], [None, '*'],
    'X', [None, '/'], 'X', [None, '-'], 'X', [None, '+'], 'X', 'X',
    [Piece('b', -9, is_dama=False), '/'], 'X', [Piece('b', 6, is_dama=False), '*'], 'X',
    [Piece('b', -1, is_dama=False), '+'], 'X', [Piece('b', 4, is_dama=False), '-'],
    [Piece('b', 0, is_dama=False), '-'], 'X', [Piece('b', -3, is_dama=False), '+'], 'X',
    [Piece('b', 10, is_dama=False), '*'], 'X', [Piece('b', -7, is_dama=False), '/'], 'X',
    'X', [Piece('b', -11, is_dama=False), '+'], 'X', [Piece('b', 8, is_dama=False), '-'],
    'X', [Piece('b', -5, is_dama=False), '/'], 'X', [Piece('b', 2, is_dama=False), '*']
]


Include the board state in your code (Place it after the Piece class is created).

"""

# %%
instruction = """
I have an initial board state (A 1-dimensional array indicated as a Python list). 
I want you to create a code that takes in a board state as an input with the function name 'func1'.
Take note that focus on each function's logic only.

First, create a Piece class that has the attributes:
1. color: Indicates the piece's color (e.g., "r" for red, "b" for blue).
2. value: The numerical value assigned to that piece.
3. is_dama: A Boolean indicating whether the piece is promoted (dama/king) or not.
4. index: this has a default value of 0. This is the position of a piece on the board_state. This should be assigned during the func1 function call.
5. name: should be a string with the format 'name, value'
A piece’s position is determined by its index (0 to 63) in the board list (excluding unusable squares).

The piece should have these dunder methods:
__repr__: it should look like this Piece('r', 2, is_dama=False)
__eq__: it should return a boolean if another object is+ an instance of the Piece class, and their names should be equal
__hash__: the hash of its name


func1 should follow these logic:

1. The function should iterate on each element of the board state. Enumerate the board state so you can get the index and the element.
2. If the element is a string 'X', do nothing.
3. If the element is a List, check the first element of that list.
4. If the first element is None, do nothing. Else, if it is an instance of the Piece class, AND if the piece's color is 'r', assign an attribute 'index' to the Piece object its index (piece.index = index).
5. Then, call the func2 function, capture its returned key:value pair, and update the valid_moves dictionary with this data.
6. After func2 returns the key, value tuple pair of valid moves, merge this pair into the valid_moves dictionary so that all pieces’ moves are recorded.
7. Print the dictionary of all valid moves.



Logic for func2:
1. The function takes in a Piece object.
2. Check if the piece is a dama. If it is a dama, run the function func3. Else, proceed with the logic below.
3. With its index as its position on the board (source index), add 7 to perform a forward left movement, and add 9 to perform a forward right movement, each of these results is a destination index.
4. For each destination index, first check if the index is within the valid range of the board state by ensuring it is less than len(board_state). Then, access the destination square using board_state[destination_index]. If the index is out-of-range, consider the move invalid; otherwise, use it to check the board state.
5. If the destination square is a list, access its first element. If the first element is None, consider it a valid move; otherwise, if it is an instance of the Piece class,or if it is a string 'X', consider it an invalid move."
6. Return a key, value tuple pair of the piece source index with a list of its valid moves ONLY.



Logic for func3:
1. The function takes in a Piece object.
2. Instantiate these variables 'fl, fr, bl, br' with the values, 7, 9, -9, -7 respectively. Store these in a list called dia.
3. Iterate each element on the dia list. Call the element 'mv'.
4. Instantiate a variable called 'holder' as an empty list. This will be used to store temporary moves.
5. Get the value of the piece's index, store it on a variable 'src'.
6. Create an inner loop with the logic below:
    a. Add 'src' and 'mv', the result being stored to 'src'.
    b. If the board with the index 'src' is a list, and the first element of the list is None, consider src as a valid move. Append src to holder.
    c. Else, break the loop.
7. After the inner loop breaks, convert holder into a tuple. Append the converted holder into the list of valid moves.
8. After all elements of the dia list are iterated, return a list of valid moves for the piece, to be returned to func2.



Here is the board_state:

[
    [Piece('r', 2, is_dama=False), '*'], 'X', [Piece('r', -5, is_dama=False), '/'], 'X',
    [Piece('r', 8, is_dama=False), '-'], 'X', [Piece('r', -11, is_dama=False), '+'], 'X',
    'X', [Piece('r', -7, is_dama=False), '/'], 'X', [Piece('r', 10, is_dama=False), '*'], 'X',
    [Piece('r', -3, is_dama=False), '+'], 'X', [Piece('r', 0, is_dama=False), '-'],
    [Piece('r', 4, is_dama=False), '-'], 'X', [Piece('r', -1, is_dama=False), '+'], 'X',
    [Piece('r', 6, is_dama=False), '*'], 'X', [Piece('r', -9, is_dama=False), '/'], 'X',
    'X', [None, '+'], 'X', [None, '-'], 'X', [None, '/'], 'X', [None, '*'], [None, '*'],
    'X', [None, '/'], 'X', [None, '-'], 'X', [None, '+'], 'X', 'X',
    [Piece('b', -9, is_dama=False), '/'], 'X', [Piece('b', 6, is_dama=False), '*'], 'X',
    [Piece('b', -1, is_dama=False), '+'], 'X', [Piece('b', 4, is_dama=False), '-'],
    [Piece('b', 0, is_dama=False), '-'], 'X', [Piece('b', -3, is_dama=False), '+'], 'X',
    [Piece('b', 10, is_dama=False), '*'], 'X', [Piece('b', -7, is_dama=False), '/'], 'X',
    'X', [Piece('b', -11, is_dama=False), '+'], 'X', [Piece('b', 8, is_dama=False), '-'],
    'X', [Piece('b', -5, is_dama=False), '/'], 'X', [Piece('b', 2, is_dama=False), '*']
]


Include the board state in your code (Place it after the Piece class is created).
"""


### CODE ###

class Piece:
    def __init__(self, color, value, is_dama=0, index=0, name=""):
        self.color = color
        self.value = value
        self.is_dama = is_dama
        self.index = index
        self.name = f"{color}, {value}"

    def __repr__(self):
        return f"Piece('{self.color}', {self.value}, is_dama={self.is_dama})"

    def __eq__(self, other):
        if not isinstance(other, Piece):
            return False
        return self.name == other.name

    def __hash__(self):
        return hash(self.name)


# Board state
board_state = [
    [Piece('r', 2, is_dama=False), '*'], 'X', [Piece('r', -5, is_dama=False), '/'], 'X',
    [Piece('r', 8, is_dama=False), '-'], 'X', [Piece('r', -11, is_dama=False), '+'], 'X',
    'X', [Piece('r', -7, is_dama=False), '/'], 'X', [Piece('r', 10, is_dama=False), '*'], 'X',
    [Piece('r', -3, is_dama=False), '+'], 'X', [Piece('r', 0, is_dama=False), '-'],
    [Piece('r', 4, is_dama=False), '-'], 'X', [Piece('r', -1, is_dama=False), '+'], 'X',
    [Piece('r', 6, is_dama=False), '*'], 'X', [Piece('r', -9, is_dama=False), '/'], 'X',
    'X', [None, '+'], 'X', [None, '-'], 'X', [None, '/'], 'X', [None, '*'], [None, '*'],
    'X', [None, '/'], 'X', [None, '-'], 'X', [None, '+'], 'X', 'X',
    [Piece('b', -9, is_dama=False), '/'], 'X', [Piece('b', 6, is_dama=False), '*'], 'X',
    [Piece('b', -1, is_dama=False), '+'], 'X', [Piece('b', 4, is_dama=False), '-'],
    [Piece('b', 0, is_dama=False), '-'], 'X', [Piece('b', -3, is_dama=False), '+'], 'X',
    [Piece('b', 10, is_dama=False), '*'], 'X', [Piece('b', -7, is_dama=False), '/'], 'X',
    'X', [Piece('b', -11, is_dama=False), '+'], 'X', [Piece('b', 8, is_dama=False), '-'],
    'X', [Piece('b', -5, is_dama=False), '/'], 'X', [Piece('b', 2, is_dama=False), '*']
]


def func1(board_state):
    valid_moves = {}
    for i, element in enumerate(board_state):
        if isinstance(element, str) and element == 'X':
            continue
        elif isinstance(element, list):
            first_element = element[0]
            if first_element is None:
                continue
            elif isinstance(first_element, Piece) and first_element.color == 'r':
                piece = first_element
                piece.index = i
                key, value = func2(piece)
                valid_moves.update({key: value})
    print(valid_moves)


def func2(piece):
    if piece.is_dama:
        return func3(piece)
    else:
        moves = []
        for mv in [7, 9, -9, -7]:
            src = piece.index
            holder = []
            for _ in range(abs(mv)):
                src += mv
                if board_state[src] is not None and isinstance(board_state[src], list) and board_state[src][0] is None:
                    holder.append(src)
                else:
                    break
            moves.extend(holder)
        return (piece.index, moves)


def func3(piece):
    dia = [7, 9, -9, -7]
    valid_moves = []
    for mv in dia:
        src = piece.index
        holder = []
        while True:
            src += mv
            if board_state[src] is not None and isinstance(board_state[src], list) and board_state[src][0] is None:
                holder.append(src)
            else:
                break
        valid_moves.extend(holder)
    return (piece.index, tuple(valid_moves))


func1(board_state)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 168
#     164         valid_moves.extend(holder)
#     165     return (piece.index, tuple(valid_moves))
# --> 168 func1(board_state)
#
# Cell In[2], line 129, in func1(board_state)
#     127             piece = first_element
#     128             piece.index = i
# --> 129             key, value = func2(piece)
#     130             valid_moves.update({key: value})
#     131 print(valid_moves)
#
# Cell In[2], line 144, in func2(piece)
#     142 for _ in range(abs(mv)):
#     143     src += mv
# --> 144     if board_state[src] is not None and isinstance(board_state[src], list) and board_state[src][0] is None:
#     145         holder.append(src)
#     146     else:
#
# IndexError: list index out of range

# %% [markdown]
# # Instruction Backup (LAtest 03-07-2025)

# %% [markdown]
# ### This one is kinda getting it

# %%
instruction = f"""
I have an initial board state (A 1-dimensional array indicated as a Python list). 
I want you to create a code that takes in a board state as an input with the function name 'func1'.

First, create a Piece class that has the attributes:
1. color: Indicates the piece's color (e.g., "r" for red, "b" for blue).
2. value: The numerical value assigned to that piece.
3. is_dama: A Boolean indicating whether the piece is promoted (dama/king) or not.
4. index: this has a default value of 0. This is the position of a piece on the board_state. This should be assigned during the func1 function call.
5. name: should be a string with the format 'name, value'
A piece’s position is determined by its index (0 to 63) in the board list (excluding unusable squares).

The piece should have these dunder methods:
__repr__: it should look like this Piece('r', 2, is_dama=False)
__eq__: it should return a boolean if another object is+ an instance of the Piece class, and their names should be equal
__hash__: the hash of its name


func1 should follow these logic:

1. The function should iterate on each element of the board state. Enumerate the board state so you can get the index (i) and the element.
2. If the element is a string 'X', do nothing.
3. If the element is a List, check the first element of that list.
4. If the first element is None, do nothing. 
5. Else, if it is an instance of the Piece class, if the piece's color is 'r', AND if the piece is a dama, do these following logic: First, assign an attribute 'element.index' to the element its index (i). Next, call the func2 function, capture its returned key:value pair. Then, update the valid_moves dictionary with this data.
6. After func2 returns the key:value pair of valid moves, merge this pair into the valid_moves dictionary so that all pieces’ moves are recorded.
7. Print the dictionary of all valid moves.

Logic for func2:
1. The function also takes in a Piece object.
2. Instantiate a list called damamove with the values [7, 9, -9, -7] and a local empty list called moves.
3. Iterate each element on the damamove list. Call the element 'mv'.
4. For each mv in damamove, set dest_index to the piece’s index and initialize an empty list called holder.
5. Use a while True loop to keep adding the move offset (mv) to dest_index and, if the destination square is within range and empty (i.e. a list whose first element is None), append that destination index to holder. Stop when the square is occupied or out-of-bounds.
6. After the loop, convert holder into a tuple and append this tuple to moves (do not include the piece’s index in the tuple).
7. After processing all move directions, simply return the list moves.


Here is the board_state:

[
    [Piece('r', 2, is_dama=False), '*'], 'X', [Piece('r', -5, is_dama=False), '/'], 'X',
    [Piece('r', 8, is_dama=False), '-'], 'X', [Piece('r', -11, is_dama=False), '+'], 'X',
    'X', [Piece('r', -7, is_dama=False), '/'], 'X', [Piece('r', 10, is_dama=False), '*'], 'X',
    [Piece('r', -3, is_dama=False), '+'], 'X', [Piece('r', 0, is_dama=False), '-'],
    [Piece('r', 4, is_dama=False), '-'], 'X', [Piece('r', -1, is_dama=False), '+'], 'X',
    [Piece('r', 6, is_dama=False), '*'], 'X', [Piece('r', -9, is_dama=False), '/'], 'X',
    'X', [None, '+'], 'X', [None, '-'], 'X', [None, '/'], 'X', [None, '*'], [None, '*'],
    'X', [None, '/'], 'X', [None, '-'], 'X', [None, '+'], 'X', 'X',
    [Piece('b', -9, is_dama=False), '/'], 'X', [Piece('b', 6, is_dama=False), '*'], 'X',
    [Piece('b', -1, is_dama=False), '+'], 'X', [Piece('b', 4, is_dama=False), '-'],
    [Piece('b', 0, is_dama=False), '-'], 'X', [Piece('b', -3, is_dama=False), '+'], 'X',
    [Piece('b', 10, is_dama=False), '*'], 'X', [Piece('b', -7, is_dama=False), '/'], 'X',
    'X', [Piece('b', -11, is_dama=False), '+'], 'X', [Piece('b', 8, is_dama=False), '-'],
    'X', [Piece('b', -5, is_dama=False), '/'], 'X', [Piece('b', 2, is_dama=False), '*']
]


Include the board state in your code (Place it after the Piece class is created).

"""

# %%
instruction = f"""I have an initial board state (A 1-dimensional array indicated as a Python list). 
I want you to create a code that takes in a board state as an input with the function name 'func1'.

First, create a Piece class that has the attributes:
1. color: Indicates the piece's color (e.g., "r" for red, "b" for blue).
2. value: The numerical value assigned to that piece.
3. is_dama: A Boolean indicating whether the piece is promoted (dama/king) or not.
4. index: this has a default value of 0. This is the position of a piece on the board_state. This should be assigned during the func1 function call.
5. name: should be a string with the format 'name, value'
A piece’s position is determined by its index (0 to 63) in the board list (excluding unusable squares).

The piece should have these dunder methods:
__repr__: it should look like this Piece('r', 2, is_dama=False)
__eq__: it should return a boolean if another object is+ an instance of the Piece class, and their names should be equal
__hash__: the hash of its name


func1 should follow these logic:

1. The function should iterate on each element of the board state. Enumerate the board state so you can get the index and the element.
2. If the element is a string 'X', do nothing.
3. If the element is a List, check the first element of that list.
4. If the first element is None, do nothing. 
5. Else, if it is an instance of the Piece class, AND if the piece's color is 'r', AND if the piece is a dama, do these following logic: assign an attribute 'index' to the Piece object its index (piece.index = index), call the func2 function, capture its returned key:value pair, and update the valid_moves dictionary with this data.
6. After func2 returns the key:value pair of valid moves, merge this pair into the valid_moves dictionary so that all pieces’ moves are recorded.
7. Print the dictionary of all valid moves.

Logic for func2:
1. The function also takes in a Piece object.
2. Instantiate a list called damamove with the values [7, 9, -9, -7] and a local empty list called moves.
3. Iterate each element on the damamove list. Call the element 'mv'.
4. Set dest_index as the piece's index. Instantiate an empty list called 'holder'.
5. Create a while True loop.
6. Inside the while True loop, set the value of dest_index as the sum of the previous dest_index and mv.
7. Check if the index is within the valid range of the board state by ensuring it is greater than or equal to 0, and less than len(board_state).
8. If it satisfies the condition, access the destination square using board_state[dest_index]. If it doesn't, break the while True loop.
9. If the destination square is an instance of a list, and the first element of the list is None, append the destination index to holder. Else, break the while True loop.
10. After the while True loop breaks, convert the holder list into a tuple, and append it to 'moves'.
11. After iterating all elements on the dia list, return the pair of piece index and the list 'moves'.


Here is the board_state:

{board_state}


Include the board state in your code (Place it after the Piece class is created).
"""


# 3. With each destination index, use it to check on the board state.
# 4. If it is a list, check the first element on the list. If it is an instance of the Piece class, then it is an invalid move.
# 5. If it is not an instance of the Piece class, it IS a valid move.
# 6. Else, if it is a string 'X', it is an invalid move.
# 7. Do not include invalid moves to the valid moves of a Piece.
# 8. Return the piece source index and the valid moves by this tuple format: (source index, [valid moves]).

# %%
instruction = f"""I have an initial board state (A 1-dimensional array indicated as a Python list). 
I want you to create a code that takes in a board state as an input with the function name 'func1'. Strictly follow the logic when creating the code.

First, create a Piece class that has the attributes:
1. color: Indicates the piece's color (e.g., "r" for red, "b" for blue).
2. value: The numerical value assigned to that piece.
3. is_dama: A Boolean indicating whether the piece is promoted (dama/king) or not.
4. index: this has a default value of 0. This is the position of a piece on the board_state. This should be assigned during the func1 function call.
5. name: should be a string with the format 'name, value'
A piece’s position is determined by its index (0 to 63) in the board list (excluding unusable squares).

The piece should have these dunder methods:
__repr__: it should look like this Piece('r', 2, is_dama=False)
__eq__: it should return a boolean if another object is+ an instance of the Piece class, and their names should be equal
__hash__: the hash of its name


func1 should follow these logic:

1. The function should iterate on each element of the board state. Enumerate the board state so you can get the index and the element.
2. If the element is a string 'X', do nothing.
3. If the element is a List, check the first element of that list.
4. If the first element is None, do nothing. Else, if it is an instance of the Piece class, AND if the piece's color is 'r', assign an attribute 'index' to the Piece object its index (piece.index = index).
5. Then, check if the piece is a dama. If it is a dama, run the function func3 and store it to a variable 'res'. Else, run the function func2 and store it to a variable 'res'. 
6. With the value of the res, update the valid_moves dictionary with this data.
7. After func2 returns the key:value pair of valid moves, merge this pair into the valid_moves dictionary so that all pieces’ moves are recorded.
8. Print the dictionary of all valid moves.



Logic for func2:
1. The function takes in a Piece object.
2. Instantiate a list called normmove with the values [7, 9] and a local empty list called moves.
3. For each element inside normmove, add it to the piece's index (source index). Each of these results is a destination index.
4. For each destination index, first check if the index is within the valid range of the board state by ensuring it is greater than or equal to 0, and less than len(board_state). If the index is out-of-range, consider the move invalid. Else, access the destination square using board_state[destination_index].
5. If the destination square is a list, access its first element. 
6. If the first element is None, consider it a valid move. Else, if the destination square is not a list, do nothing.
7. Append the valid move on the 'moves' list.
8. Return a key, value dictionary of the piece source index with a list of its valid moves ONLY.



Logic for func3:
1. The function also takes in a Piece object.
2. Instantiate a list called damamove with the values [7, 9, -9, -7] and a local empty list called moves.
3. Iterate each element on the damamove list. Call the element 'mv'.
4. Set dest_index as the piece's index. Instantiate an empty list called 'holder'.
5. Create an infinite while True loop.
6. Inside the while True loop, set the value of dest_index as the sum of the previous dest_index and mv.
7. Check if the index is within the valid range of the board state by ensuring it is greater than or equal to 0, and less than len(board_state).
8. If it satisfies the condition, access the destination square using board_state[dest_index]. If it doesn't, break the while True loop.
9. If the destination square is an instance of a list, and the first element of the list is None, append the destination index to holder. Else, break the while True loop.
10. After the while True loop breaks, convert the holder list into a tuple, and append it to 'moves'.
11. After iterating all elements on the dia list, return the pair of piece index and the list 'moves'.



Here is the board_state:

{board_state}


Include the board state in your code (Place it after the Piece class is created).
"""






# Logic for func3:
# 1. The function also takes in a Piece object.
# 2. Instantiate a list called func3_only with the values [7, 9, -9, -7].
# 3. Iterate each element on the dia list. Call the element 'mv'.
# 4. Instantiate a variable called 'holder' as an empty list. This will be used to store temporary moves.
# 5. Get the value of the piece's index, store it on a variable 'src'.
# 6. Print the value of src.
# 6. For each directional offset mv in the list dia (which is [7, 9, -9, -7]), do the following:
#     a. Initialize an empty list called holder and set a local variable src = piece.index.
#     b. Enter an inner loop that repeatedly checks if (src + mv) is in bounds (i.e. 0 ≤ src + mv < len(board_state)) and if board_state[src + mv] is a list whose first element is None. If so, update src = src + mv and append src to holder; otherwise, break the inner loop.
#     c. After the inner loop terminates for that directional move, convert holder into a tuple and append this tuple to a list of valid moves.
# 7. After the inner loop terminates for that mv, convert holder into a tuple and append it to a list of valid moves (one tuple per directional offset).
# 8. After processing all directional offsets in dia, return a key, value tuple pair where the key is the piece’s source index and the value is the complete list (containing one tuple per directional offset) of valid moves for the dama piece.

# %%
code = """



board_state = [
    [Piece('r', 2, is_dama=False), '*'], 'X', [Piece('r', -5, is_dama=False), '/'], 'X',
    [Piece('r', 8, is_dama=False), '-'], 'X', [Piece('r', -11, is_dama=False), '+'], 'X',
    'X', [Piece('r', -7, is_dama=False), '/'], 'X', [Piece('r', 10, is_dama=False), '*'], 'X',
    [Piece('r', -3, is_dama=False), '+'], 'X', [Piece('r', 0, is_dama=False), '-'],
    [Piece('r', 4, is_dama=False), '-'], 'X', [Piece('r', -1, is_dama=False), '+'], 'X',
    [Piece('r', 6, is_dama=False), '*'], 'X', [Piece('r', -9, is_dama=False), '/'], 'X',
    'X', [None, '+'], 'X', [None, '-'], 'X', [None, '/'], 'X', [None, '*'], [None, '*'],
    'X', [None, '/'], 'X', [None, '-'], 'X', [None, '+'], 'X', 'X',
    [Piece('b', -9, is_dama=False), '/'], 'X', [Piece('b', 6, is_dama=False), '*'], 'X',
    [Piece('b', -1, is_dama=False), '+'], 'X', [Piece('b', 4, is_dama=False), '-'],
    [Piece('b', 0, is_dama=False), '-'], 'X', [Piece('b', -3, is_dama=False), '+'], 'X',
    [Piece('b', 10, is_dama=False), '*'], 'X', [Piece('b', -7, is_dama=False), '/'], 'X',
    'X', [Piece('b', -11, is_dama=False), '+'], 'X', [Piece('b', 8, is_dama=False), '-'],
    'X', [Piece('b', -5, is_dama=False), '/'], 'X', [Piece('b', 2, is_dama=False), '*"]
]


"""

# %%
instruction=f"""
Return this code only:

{code}

"""

# %% [markdown]
# ### **DeepSeek Run**

# %%
from langchain_ollama import ChatOllama
from langchain_core.output_parsers import StrOutputParser

llm = ChatOllama(
    model="deepseek-r1:8b",
    streaming=True,
    temperature=0,
    # other params...
    # llama3.2:3b-instruct-q8_0
)

chain = llm # | StrOutputParser()

async for event in chain.astream_events(instruction, version="v2"):
    kind = event["event"]
    if kind == "on_chat_model_stream":
        print(event["data"]["chunk"].content, end="|", flush=True)
# Out:
# <think>|
# |Okay|,| I| need| to| fix| any| syntax| errors| in| the| provided| Python| code|.| Let| me| go| through| each| part| step| by| step|.
#
# |First|,| looking| at| the| `|Piece|`| class|.| The| constructor| has| parameters| color|,| value|,| is|_d|ama|=| False|,| index| =| |0|,| name|="|".| That| looks| fine| except| for| the| default| values|.| In| Python|,| default| parameter| values| should| be| immutable| types|,| but| here| they| are| using| integers| and| strings| which| are| fine|.| So| no| issues| there|.
#
# |Next|,| the| `|__|repr|__|`| method| returns| a| string| with| self|.color|,| self|.value|,| is|_d|ama|,| and| index|.| The| format| seems| correct|,| using| f|-|strings| properly|.
#
# |The| `|__|eq|__|`| method| checks| if| other| is| an| instance| of| Piece| and| compares| names|.| That| makes| sense| for| equality| based| on| name|.
#
# |The| `|__|hash|__|`| method| uses| the| name| attribute|'s| hash|.| Since| each| piece| has| a| unique| name|,| this| should| work| for| hashing| in| dictionaries| or| sets|.
#
# |Moving| to| `|func|1|`,| it| initializes| valid|_moves| as| a| dictionary|.| Then| iter|ates| over| board|_state| elements|.| If| an| element| is| '|X|',| it| skips|.| If| it|'s| a| list|,| checks| if| the| first| element| is| None|;| if| so|,| skips|.| Otherwise|,| if| it|'s| a| Piece| of| color| '|r|',| increments| index|_counter| and| sets| piece|.index| to| it|.| Then| calls| func|2| and| updates| valid|_moves| with| key|-value| pairs|.
#
# |Wait|,| in| the| loop|,| for| each| i|,| element| in| enumerate|(board|_state|),| but| board|_state| seems| to| be| a| list| where| some| elements| are| lists| themselves|.| For| example|,| in| the| test| case|,| the| first| element| is| [|Piece|('|r|',| |2|,...|),| '*|'],| which| is| a| list|.| So| when| element| is| this| list|,| it|'s| processed| correctly|.
#
# |In| func|1|,| after| getting| piece|.index| =| index|_counter|,| then| key| is| (|piece|.color|,| piece|.value|).| Then| value| is| func|2|(piece|).| But| in| the| test| case|,| when| i|=|0|,| element| is| [|Piece|('|r|',| |2|),| '*|'],| so| first|_element| is| the| Piece|.| So| it|'s| added| to| valid|_moves| with| key| ('|r|',| |2|)| and| value| from| func|2|.
#
# |Now| looking| at| func|2|.| It| starts| by| checking| if| not| piece|.is|_d|ama|.| If| true|,| it| calculates| forward|_left|,| etc|.,| based| on| moving| in| certain| directions|.| Else|,| for| d|ama| pieces|,| it| checks| in| four| diagonal| directions|.
#
# |Wait|,| but| in| the| code|,| after| the| initial| while| loops| for| non|-d|ama| pieces|,| it| returns| a| tuple| with| (|color|,| value|)| and| the| list| of| indices|.| For| d|ama| pieces|,| it|'s| similar| but| uses| different| directions|.
#
# |But| I| notice| that| in| func|2|,| when| handling| non|-d|ama| pieces|,| after| the| while| loop|,| it| returns| (|piece|.color|,| piece|.value|),| [|forward|_left|,| ...|].| But| in| the| test| case|,| when| a| piece| is| not| d|ama|,| like| the| first| red| piece| at| index| |0|,| it| should| have| valid| moves|.
#
# |Wait|,| but| looking| at| how| func|1| calls| func|2|:| it|'s| using| the| return| value| as| the| value| for| valid|_moves|.| So| if| func|2| returns| (|color|,| value|),| [|list|],| then| in| valid|_moves|,| each| key| is| a| tuple| of| color| and| value|,| and| the| value| is| another| tuple| or| list|.
#
# |But| in| the| test| case|,| when| func|1| is| called|,| it| just| prints| the| result| without| using| the| return| value|,| so| maybe| that|'s| not| an| issue|.| But| perhaps| the| function| should| be| returning| something| else|.
#
# |Another| thing|:| in| the| while| loops| for| non|-d|ama| pieces|,| the| code| checks| if| the| next| position| is| within| bounds|.| For| example|,| for| forward|_left|,| it| moves| |7| steps| up| and| |1| right|.| So| it| needs| to| ensure| that| the| new| row| and| column| are| within| the| board|'s| limits|.
#
# |Wait|,| but| how| is| the| board| structured|?| The| test| case| shows| a| |2|D| list| with| varying| lengths|.| It| might| not| be| a| perfect| grid|,| so| checking| for| bounds| is| essential|.
#
# |Also|,| in| the| code|,| when| handling| non|-d|ama| pieces|,| after| moving|,| it| checks| if| the| next| position| is| within| the| board|'s| rows| and| columns|.| But| how| are| the| rows| and| columns| defined|?| For| example|,| if| the| piece| is| at| row| i|,| column| j|,| then| moving| up| |7| would| take| it| to| i|-|7|,| which| might| be| negative| or| beyond| the| list|'s| length|.
#
# |So| perhaps| adding| a| check| like| if| (|i| -| steps|)| >=|0| and| (|j| +| steps|)| < len|(board|[i|])| or| something| similar|.| But| in| the| current| code|,| it| just| proceeds| without| such| checks|,| which| could| cause| index| errors|.
#
# |Another| potential| issue| is| that| in| func|2|,| when| handling| non|-d|ama| pieces|,| after| moving| forward|_left|,| it|'s| checking| if| board|[i| -| |7|][|j| +| |1|]| is| None|.| If| so|,| it| adds| to| the| list|.| But| this| might| not| correctly| handle| all| edge| cases|,| like| going| beyond| the| board|'s| limits|.
#
# |Also|,| looking| at| how| the| valid|_moves| are| stored| in| func|1|:| each| piece|'s| moves| are| added| as| key|-value| pairs| where| the| key| is| (|color|,| value|)| and| the| value| is| a| list| of| possible| indices|.| But| when| multiple| pieces| have| the| same| color| and| value|,| their| moves| could| overwrite| each| other| in| the| dictionary|,| leading| to| incorrect| data|.
#
# |For| example|,| if| two| different| pieces| have| the| same| color| and| value|,| their| valid|_moves| would| be| stored| under| the| same| key|,| potentially| causing| only| the| last| one|'s| moves| to| be| retained|.
#
# |So| perhaps| using| a| different| structure| for| valid|_moves|,| like| a| list| of| dictionaries| or| another| way| to| associate| each| piece| uniquely|,| might| be| better|.| But| that|'s| more| of| a| design| choice| than| a| syntax| error|.
#
# |Looking| back| at| the| code|,| I| don|'t| see| any| obvious| syntax| errors|.| The| indentation| seems| correct|,| and| all| functions| are| properly| defined|.| The| test| case| calls| func|1| with| the| provided| board|_state|,| which| is| a| large| list|.
#
# |Wait|,| but| in| Python|,| when| you| have| a| |2|D| list|,| each| row| might| have| varying| lengths|.| So| when| accessing| elements| like| board|[i|][|j|],| it|'s| possible| that| j| goes| beyond| the| length| of| that| particular| row|,| causing| an| IndexError|.| The| code| doesn|'t| handle| this|,| so| if| a| piece| tries| to| move| into| a| position| where| j| is| out| of| bounds| for| that| row|,| it| would| crash|.
#
# |So| perhaps| adding| bounds| checking| in| func|2| is| necessary|.| For| example|,| when| moving| forward|_left|,| check| if| i| -| |7| >=|0| and| j| +|1| < len|(board|[i|-|7|])|.
#
# |But| again|,| this| is| more| about| logic| than| syntax|.
#
# |Another| thing|:| the| `|func|1|`| function| doesn|'t| return| anything|,| which| is| fine| if| it|'s| only| used| to| print| or| process| internally|.| But| in| a| larger| context|,| it| might| be| expected| to| return| something|.
#
# |In| summary|,| while| there| are| potential| logical| issues| like| bounds| checking| and| handling| varying| row| lengths|,| I| don|'t| see| any| syntax| errors| in| the| provided| code|.
# |</think>|
#
# |The| provided| code| defines| a| `|Piece|`| class| with| attributes| and| methods|,| along| with| functions| `|func|1|`| and| `|func|2|`| to| handle| game| logic|.| Here|'s| a| breakdown| of| the| key| components|:
#
# |###| `|Piece|`| Class|
# |-| **|Attributes|**:| `|color|`,| `|value|`,| `|is|_d|ama|`,| `|index|`,| `|name|`
# |-| **|Methods|**|:
# | | -| `|__|init|__|`:| Initializes| the| piece| with| given| attributes|.
# | | -| `|__|repr|__|`:| Returns| a| string| representation| of| the| piece|.
# | | -| `|__|eq|__|`:| Comp|ares| pieces| based| on| their| `|name|`| attribute|.
# | | -| `|__|hash|__|`:| Uses| the| `|name|`| for| hashing|.
#
# |###| `|func|1|`
# |-| **|Purpose|**:| Processes| each| element| in| the| board| state| to| identify| valid| moves| for| red| pieces|.
# |-| **|Logic|**|:
# | | -| Iter|ates| over| each| element| in| `|board|_state|`.
# | | -| Checks| if| an| element| is| a| list| containing| a| `|Piece|`| of| color| '|r|'.
# | | -| Calls| `|func|2|`| to| get| valid| moves| and| updates| a| dictionary| with| move| information|.
#
# |###| `|func|2|`
# |-| **|Purpose|**:| Determines| valid| moves| for| a| given| piece| based| on| its| type| (|d|ama| or| non|-d|ama|).
# |-| **|Logic|**|:
# | | -| For| non|-d|ama| pieces|,| checks| forward| and| backward| moves| in| specific| directions|.
# | | -| For| d|ama| pieces|,| checks| diagonal| moves|.
# | | -| Collect|s| indices| of| valid| moves|.
#
# |###| Key| Consider|ations|
# |1|.| **|Bounds| Checking|**:| The| code| does| not| check| if| moves| go| beyond| the| board|'s| boundaries|,| potentially| causing| errors|.
# |2|.| **|Row| Length| Vari|ability|**:| Each| row| may| have| different| lengths|,| leading| to| index| errors| when| accessing| columns|.
# |3|.| **|Move| Over|writing|**:| Using| a| dictionary| for| valid| moves| can| overwrite| entries| if| multiple| pieces| have| the| same| color| and| value|.
#
# |###| Conclusion|
# |The| code| is| synt|act|ically| correct| but| has| logical| issues| that| should| be| addressed| for| robust| functionality|.||

# %% [markdown]
# ### **LLaMa Run**

# %%
from langchain_ollama import ChatOllama
from langchain_core.output_parsers import StrOutputParser

llm = ChatOllama(
    model="llama3.2:3b-instruct-q8_0",
    streaming=True,
    temperature=0,
    # other params...
    # llama3.2:3b-instruct-q8_0
)

chain = llm # | StrOutputParser()

async for event in chain.astream_events(instruction, version="v2"):
    kind = event["event"]
    if kind == "on_chat_model_stream":
        print(event["data"]["chunk"].content, end="|", flush=True)
# Out:
# ```|python|
# |board|_state| =| [
# |   | [|Piece|('|r|',| |2|,| is|_d|ama|=False|),| '*|'],| '|X|',| [|Piece|('|r|',| -|5|,| is|_d|ama|=False|),| '/|'],| '|X|',
# |   | [|Piece|('|r|',| |8|,| is|_d|ama|=False|),| '-|'],| '|X|',| [|Piece|('|r|',| -|11|,| is|_d|ama|=False|),| '+|'],| '|X|',
# |   | '|X|',| [|Piece|('|r|',| -|7|,| is|_d|ama|=False|),| '/|'],| '|X|',| [|Piece|('|r|',| |10|,| is|_d|ama|=False|),| '*|'],| '|X|',
# |   | [|Piece|('|r|',| -|3|,| is|_d|ama|=False|),| '+|'],| '|X|',| [|Piece|('|r|',| |0|,| is|_d|ama|=False|),| '-|'],
# |   | [|Piece|('|r|',| |4|,| is|_d|ama|=False|),| '-|'],| '|X|',| [|Piece|('|r|',| -|1|,| is|_d|ama|=False|),| '+|'],| '|X|',
# |   | [|Piece|('|r|',| |6|,| is|_d|ama|=False|),| '*|'],| '|X|',| [|Piece|('|r|',| -|9|,| is|_d|ama|=False|),| '/|'],| '|X|',
# |   | '|X|',| [|None|,| '+|'],| '|X|',| [|None|,| '-|'],| '|X|',| [|None|,| '/|'],| '|X|',| [|None|,| '*|'],| [|None|,| '*|'],
# |   | '|X|',| [|None|,| '/|'],| '|X|',| [|None|,| '-|'],| '|X|',| [|None|,| '+|'],| '|X|',| '|X|',
# |   | [|Piece|('|b|',| -|9|,| is|_d|ama|=False|),| '/|'],| '|X|',| [|Piece|('|b|',| |6|,| is|_d|ama|=False|),| '*|'],| '|X|',
# |   | [|Piece|('|b|',| -|1|,| is|_d|ama|=False|),| '+|'],| '|X|',| [|Piece|('|b|',| |4|,| is|_d|ama|=False|),| '-|'],
# |   | [|Piece|('|b|',| |0|,| is|_d|ama|=False|),| '-|'],| '|X|',| [|Piece|('|b|',| -|3|,| is|_d|ama|=False|),| '+|'],| '|X|',
# |   | [|Piece|('|b|',| |10|,| is|_d|ama|=False|),| '*|'],| '|X|',| [|Piece|('|b|',| -|7|,| is|_d|ama|=False|),| '/|'],| '|X|',
# |   | '|X|',| [|Piece|('|b|',| -|11|,| is|_d|ama|=False|),| '+|'],| '|X|',| [|Piece|('|b|',| |8|,| is|_d|ama|=False|),| '-|'],
# |   | '|X|',| [|Piece|('|b|',| -|5|,| is|_d|ama|=False|),| '/|'],| '|X|',| [|Piece|('|b|',| |2|,| is|_d|ama|=False|),| '*|']
# |]
# |```||
