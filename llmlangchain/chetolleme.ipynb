# %%
from langchain_ollama import ChatOllama
from langchain_core.output_parsers import StrOutputParser

llm = ChatOllama(
    model="deepseek-r1:8b",
    streaming=True,
    temperature=0,
    # other params...
    # llama3.2:3b-instruct-q8_0
)

llm.invoke("wassup!")
# Out:
# AIMessage(content="<think>\n\n</think>\n\nHey! Not much, just here to help you out. What's up with you? 😄", additional_kwargs={}, response_metadata={'model': 'deepseek-r1:8b', 'created_at': '2025-02-18T06:56:23.096781503Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4687702006, 'load_duration': 17857891, 'prompt_eval_count': 7, 'prompt_eval_duration': 190000000, 'eval_count': 25, 'eval_duration': 4479000000, 'message': Message(role='assistant', content='', images=None, tool_calls=None)}, id='run-7a2f924d-9bbb-487e-a693-8797ec0fbfe4-0', usage_metadata={'input_tokens': 7, 'output_tokens': 25, 'total_tokens': 32})

# %%
x = """# Instruction: Determining Valid Moves for Red Pieces

**Objective:**  
Develop an assistant that creates a code that calculates all valid moves for every red piece on a board given a specific board state.

---

## Board State Overview

- **Structure:**  
  The board is represented as a Python list (1D array) of 64 elements, similar to a standard checkers board with some modifications.
  
- **Element Types:**  
  Each element is either:
  - A string `"X"`, representing an unusable square, or
  - A list in the format `[piece, operator]`, where:
    - **piece:** A `Piece` object or `None` (if the square is empty).
    - **operator:** A mathematical operator (e.g., `"+"`, `"-"`, `"×"`, or `"÷"`) associated with that square.

---

### The `Piece` Object

A `Piece` object includes:
- **color:** The piece's color (e.g., `"r"` for red, `"b"` for blue).
- **value:** A numerical value assigned to the piece.
- **is_dama:** A Boolean indicating if the piece is promoted (dama/king).

> **Note:**  
> The position of a piece is determined by its index (0 to 63) in the board list, **ignoring unusable squares**.

---

### Example Board State

```python
board_state = [
    [None, '*'], 'X', [None, '/'], 'X', [None, '-'], 'X', [None, '+'], 'X', 'X',
    [None, '/'], 'X', [None, '*'], 'X', [Piece('r', -11, is_dama=False), '+'], 'X',
    [Piece('r', 0, is_dama=False), '-'], [None, '-'], 'X', [None, '+'], 'X', 
    [Piece('r', 6, is_dama=True), '*'], 'X', [Piece('r', -9, is_dama=False), '/'], 'X', 'X',
    [None, '+'], 'X', [None, '-'], 'X', [None, '/'], 'X', [None, '*'], [Piece('b', 0, is_dama=True), '*'], 'X',
    [None, '/'], 'X', [None, '-'], 'X', [None, '+'], 'X', 'X', [None, '/'], 'X',
    [None, '*'], 'X', [None, '+'], 'X', [None, '-'], [Piece('r', -5, is_dama=True), '-'], 'X',
    [None, '+'], 'X', [None, '*'], 'X', [None, '/'], 'X', 'X', [None, '+'], 'X',
    [None, '-'], 'X', [None, '/'], 'X', [None, '*']
]

"""

# %%
chain = llm | StrOutputParser()

# %%
async for event in chain.astream_events(x, version="v2"):
    kind = event["event"]
    if kind == "on_chat_model_stream":
        print(event["data"]["chunk"].content, end="|", flush=True)
# Out:
# <think>|
# |Okay|,| so| I| need| to| figure| out| how| to| determine| all| valid| moves| for| every| red| piece| on| a| check|ers| board| based| on| the| given| board| state|.| Hmm|,| let|'s| break| this| down| step| by| step|.
#
# |First|,| I| should| understand| the| structure| of| the| board|.| The| board| is| represented| as| a| Python| list| with| |64| elements|.| Each| element| can| be| either| "|X|"| (|un|usable| square|)| or| a| list| containing| a| Piece| object| and| an| operator|.| Wait|,| no|,| actually|,| looking| back| at| the| problem| statement|,| each| element| is| either| a| string| "|X|"| or| a| list| in| the| format| [|piece|,| operator|].| So| if| it|'s| not| "|X|",| then| it|'s| a| piece| along| with| an| operator|.
#
# ...

# %% [markdown]
# ##### THIS IS FOR PRESERVATION PURPOSES

# %%
async for event in chain.astream_events(x, version="v2"):
    kind = event["event"]
    if kind == "on_chat_model_stream":
        print(event["data"]["chunk"].content, end="|", flush=True)

# %%
llm.invoke("""Instruction: You are an assistant tasked to find all valid moves for all red pieces given a board state

- The board is similar to a standard checkers board, with slightly variations.
- Each piece has an associated numerical value.
- Each usable square on the board contains a mathematical operator (such as +, –, ×, ÷).
- When a piece captures an enemy piece, you use the numerical values of both pieces and the operator on the destination square to calculate a score (e.g. if a piece with value 3 captures a piece with value 5 on a square marked with "×", then 5 × 3 = 15 is added to the total).
- The board given to you will be in a python List format, which is converted into a 1d array.
- regular movements

Board state:
- the board is a Python List (1D array) containing 64 items of either a smaller list, or the string 'X'.
- The 'X' indicates an unusable square, similar to checkers
- the smaller list contains a piece-operator pair. None indicates that there is no piece on that square, the operator indicates the symbol on that square.
- if there is a piece, it is indicated by using a Piece object.
- A Piece object has the attributes 'color', 'value', and 'is_dama'.
- color indicates the piece's color. value indicates the value assigned to that piece. is_dama indicates whether a piece is promoted.
- a Piece's position is indicated by its index on the board list, ranging from 0 to 63 (excluding unusable squares)


How to get a valid move for a red piece:
- a red piece can move by adding 7 to its position to go left, or adding 9 to its position to go right. this is now a destination index 
- if the item in the board using the destination index is a string 'X', do not include it on the valid moves.
-f the item in the board using the destination index is a list, check if the 1st element on the list is None. If it is none, include it on the valid moves of a piece. Else, do not include it.

List all valid moves for all red pieces by this format:
[position index]: [destination index/indeces]
[position index]: [destination index/indeces]
...

Here is the board list:
[[Piece(r, 2, is_dama=False), '*'], 'X', [Piece(r, -5, is_dama=False), '/'], 'X', [Piece(r, 8, is_dama=False), '-'], 'X', [Piece(r, -11, is_dama=False), '+'], 'X', 'X', [Piece(r, -7, is_dama=False), '/'], 'X', [Piece(r, 10, is_dama=False), '*'], 'X', [Piece(r, -3, is_dama=False), '+'], 'X', [Piece(r, 0, is_dama=False), '-'], [Piece(r, 4, is_dama=False), '-'], 'X', [Piece(r, -1, is_dama=False), '+'], 'X', [Piece(r, 6, is_dama=False), '*'], 'X', [Piece(r, -9, is_dama=False), '/'], 'X', 'X', [None, '+'], 'X', [None, '-'], 'X', [None, '/'], 'X', [None, '*'], [None, '*'], 'X', [None, '/'], 'X', [None, '-'], 'X', [None, '+'], 'X', 'X', [Piece(b, -9, is_dama=False), '/'], 'X', [Piece(b, 6, is_dama=False), '*'], 'X', [Piece(b, -1, is_dama=False), '+'], 'X', [Piece(b, 4, is_dama=False), '-'], [Piece(b, 0, is_dama=False), '-'], 'X', [Piece(b, -3, is_dama=False), '+'], 'X', [Piece(b, 10, is_dama=False), '*'], 'X', [Piece(b, -7, is_dama=False), '/'], 'X', 'X', [Piece(b, -11, is_dama=False), '+'], 'X', [Piece(b, 8, is_dama=False), '-'], 'X', [Piece(b, -5, is_dama=False), '/'], 'X', [Piece(b, 2, is_dama=False), '*']]""")
